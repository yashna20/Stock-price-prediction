# %%
# tfann : real life prediction can work on CPU and smaller than tensorflow
import numpy as np
from sklearn.preprocessing import scale
import matplotlib.pyplot as mpl
from TFANN import ANNR

# %%
# reads data from the file and create a matrix with only the dates and the prices
# to covert actual data to scale data
# delimiter : with what the data is separated
stock_data = np.loadtxt('ZBH.csv', delimiter=",",skiprows=1, usecols = (1,4))
# scales the data to smaller values
stock_data = scale(stock_data)
# gets the price and dates from the matrix
prices = stock_data[:,1].reshape(-1,1)
dates = stock_data[:,0].reshape(-1,1)
# creates a plot of the data and then displays it
mpl.plot(dates[:,0], prices[:,0])
mpl.show()

# %%
# 1 input 1 output and 50 hidden layer
# predicts internally 50 but would get 1 as resullt
# verbose : True shows data
# preprocessing data: processing dat internally
# normalization and binarization(study)
# tensorflow artificial neutral network(tfann)
